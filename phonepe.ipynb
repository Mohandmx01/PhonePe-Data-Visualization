# %%
#Install tools
# !pip install streamlit
# !pip install psycopg2
# !pip install plotly
# !pip install os
# !pip install gitpython
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import psycopg2 as sql
import streamlit as st
import plotly.express as px
import os
import json
from PIL import Image

# Rest of your code...

# %%
import streamlit as st

# %%
# !git clone https://github.com/PhonePe/pulse.git

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="C:/Users/Mohan.S/Desktop/Mohan_Project/Project_2/pulse/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            A=json.load(Data)
            for z in A['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transacion_type'].append(Name)
              clm['Transacion_count'].append(count)
              clm['Transacion_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
df_agg_trans=pd.DataFrame(clm)

# %%
# Agg_trans
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 Agg_trans
#
# NameError: name 'Agg_trans' is not defined

# %%
# Agg_user_list
path1="C:/Users/Mohan.S/Desktop/Mohan_Project/Project_2/pulse/data/aggregated/user/country/india/state/"

Agg_user_list=os.listdir(path1)
# Agg_state_list
# #Agg_state_list--> to get the list of states in India

# #<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

# #This is to extract the data's to create a dataframe

clm1={'State':[], 'Year':[],'Quater':[],'Brands':[], 'Transacion_count':[], 'Percentage':[]}
for i in Agg_state_list:
    p_i=path1+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            B=json.load(Data)
            try:
                for z in B['data']['usersByDevice']:
                  brand=z['brand']
                  count=z['count']
                  percentage=z['percentage']
                  clm1['Brands'].append(brand)
                  clm1['Transacion_count'].append(count)
                  clm1['Percentage'].append(percentage)
                  clm1['State'].append(i)
                  clm1['Year'].append(j)
                  clm1['Quater'].append(int(k.strip('.json')))

            except:
              pass

#Succesfully created a dataframe
df_agg_user=pd.DataFrame(clm1)

# %%
df_agg_user
# Out:
#                           State  Year  Quater   Brands  Transacion_count  \
# 0     andaman-&-nicobar-islands  2018       1   Xiaomi              1665
# 1     andaman-&-nicobar-islands  2018       1  Samsung              1445
# 2     andaman-&-nicobar-islands  2018       1     Vivo               982
# 3     andaman-&-nicobar-islands  2018       1     Oppo               501
# 4     andaman-&-nicobar-islands  2018       1  OnePlus               332
# ...                         ...   ...     ...      ...               ...
# 6727                west-bengal  2022       1   Lenovo            330017
# 6728                west-bengal  2022       1  Infinix            284678
# 6729                west-bengal  2022       1     Asus            280347
# 6730                west-bengal  2022       1    Apple            277752
# 6731                west-bengal  2022       1   Others           2196334
#
#       Percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# 3       0.074332
# ...

# %%
# Map_tran
path2="C:/Users/Mohan.S/Desktop/Mohan_Project/Project_2/pulse/data/map/transaction/hover/country/india/state/"

Map_tran_list=os.listdir(path2)



clm2={'State':[], 'Year':[],'Quater':[],'Districts':[], 'Transacion_count':[], 'Transacion_amount':[]}
for i in Map_tran_list:
    p_i=path2+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            C=json.load(Data)
            for z in C['data']['hoverDataList']:
                      Name=z['name']
                      count=z["metric"][0]['count']
                      amount=z["metric"][0]['amount']
                      clm2['Districts'].append(Name)
                      clm2['Transacion_count'].append(count)
                      clm2['Transacion_amount'].append(amount)
                      clm2['State'].append(i)
                      clm2['Year'].append(j)
                      clm2['Quater'].append(int(k.strip('.json')))



# #Succesfully created a dataframe
df_map_trans=pd.DataFrame(clm2)

# %%
df_map_trans
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 16827                west-bengal  2023       3
# 16828                west-bengal  2023       3
# 16829                west-bengal  2023       3
# 16830                west-bengal  2023       3
# 16831                west-bengal  2023       3
#
#                                Districts  Transacion_count  Transacion_amount
# 0      north and middle andaman district               442       9.316631e+05
# 1                 south andaman district              5688       1.256025e+07
# 2                      nicobars district               528       1.139849e+06
# 3      north and middle andaman district               825       1.317863e+06
# ...

# %%
# Map_user
path3="C:/Users/Mohan.S/Desktop/Mohan_Project/Project_2/pulse/data/map/user/hover/country/india/state/"

Map_user_list=os.listdir(path3)



clm3={'State':[], 'Year':[],'Quater':[],'Districts':[], 'RegisteredUsers':[], 'AppOpens':[]}
for i in Map_user_list:
    p_i=path3+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D["data"]["hoverData"].items():
                disctrict=z[0]
                registeredUsers=z[1]['registeredUsers']
                appOpens=z[1]['appOpens']
                clm3['Districts'].append(disctrict)
                clm3['RegisteredUsers'].append(registeredUsers)
                clm3['AppOpens'].append(appOpens)
                clm3['State'].append(i)
                clm3['Year'].append(j)
                clm3['Quater'].append(int(k.strip('.json')))



# #Succesfully created a dataframe
df_map_user=pd.DataFrame(clm3)

# %%
df_map_user
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 16831                west-bengal  2023       3
# 16832                west-bengal  2023       3
# 16833                west-bengal  2023       3
# 16834                west-bengal  2023       3
# 16835                west-bengal  2023       3
#
#                                Districts  RegisteredUsers  AppOpens
# 0      north and middle andaman district              632         0
# 1                 south andaman district             5846         0
# 2                      nicobars district              262         0
# 3      north and middle andaman district              911         0
# ...

# %%
# Top_tran
path4="C:/Users/Mohan.S/Desktop/Mohan_Project/Project_2/pulse/data/top/transaction/country/india/state/"

Top_tran_list=os.listdir(path4)



clm4={'State':[], 'Year':[],'Quater':[],'Pincodes':[], 'Transaction_count':[], 'Transaction_amount':[]}
for i in Top_tran_list:
    p_i=path2+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            E=json.load(Data)
            for z in E['data']['hoverDataList']:
                      Name=z['name']
                      count=z["metric"][0]['count']
                      amount=z["metric"][0]['amount']
                      clm4['Pincodes'].append(Name)
                      clm4['Transaction_count'].append(count)
                      clm4['Transaction_amount'].append(amount)
                      clm4['State'].append(i)
                      clm4['Year'].append(j)
                      clm4['Quater'].append(int(k.strip('.json')))



# # #Succesfully created a dataframe
df_top_trans=pd.DataFrame(clm4)

# %%
df_top_trans
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 16827                west-bengal  2023       3
# 16828                west-bengal  2023       3
# 16829                west-bengal  2023       3
# 16830                west-bengal  2023       3
# 16831                west-bengal  2023       3
#
#                                 Pincodes  Transacion_count  Transacion_amount
# 0      north and middle andaman district               442       9.316631e+05
# 1                 south andaman district              5688       1.256025e+07
# 2                      nicobars district               528       1.139849e+06
# 3      north and middle andaman district               825       1.317863e+06
# ...

# %%
# Top_user
path5="C:/Users/Mohan.S/Desktop/Mohan_Project/Project_2/pulse/data/top/user/country/india/state/"

Top_user_list=os.listdir(path5)



clm5={'State':[], 'Year':[],'Quater':[],'Pincodes':[], 'RegisteredUsers':[]}
for i in Map_user_list:
    p_i=path5+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            F=json.load(Data)
            for z in F["data"]["districts"]:
                Name=z['name']
                registeredUsers=z['registeredUsers']
                clm5['Pincodes'].append(Name)
                clm5['RegisteredUsers'].append(registeredUsers)
                clm5['State'].append(i)
                clm5['Year'].append(j)
                clm5['Quater'].append(int(k.strip('.json')))



# # #Succesfully created a dataframe
df_top_user=pd.DataFrame(clm5)

# %%
df_top_user
# Out:
#                           State  Year  Quater                  Pincodes  \
# 0     andaman-&-nicobar-islands  2018       1             south andaman
# 1     andaman-&-nicobar-islands  2018       1  north and middle andaman
# 2     andaman-&-nicobar-islands  2018       1                  nicobars
# 3     andaman-&-nicobar-islands  2018       2             south andaman
# 4     andaman-&-nicobar-islands  2018       2  north and middle andaman
# ...                         ...   ...     ...                       ...
# 6803                west-bengal  2023       3                    howrah
# 6804                west-bengal  2023       3                     nadia
# 6805                west-bengal  2023       3           purba medinipur
# 6806                west-bengal  2023       3         paschim medinipur
# 6807                west-bengal  2023       3           purba bardhaman
#
#       RegisteredUsers
# 0                5846
# 1                 632
# 2                 262
# ...

# %%
# File Coverting Data Frames to csv files
df_agg_trans.to_csv('agg_trans.csv',index=False)
df_agg_user.to_csv('agg_user.csv',index=False)
df_map_trans.to_csv('map_trans.csv',index=False)
df_map_user.to_csv('map_user.csv',index=False)
df_top_trans.to_csv('top_trans.csv',index=False)
df_top_user.to_csv('top_user.csv',index=False)

# %%
# !pip install pyscopg2
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for pyscopg2: filename=pyscopg2-66.0.2-py3-none-any.whl size=1166 sha256=4452903d821ff1430ce684bba2f9bf23607c74246c1488d0c650fec74d064619
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\26\70\50\6e6a160edf49a8312b1558e50739047e96b3b1a47f1696603e
# Successfully built pyscopg2
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\USER\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import psycopg2

mydb = psycopg2.connect(
    host="localhost",
    user="postgres",
    password="Iphone14pro",
    database="Phonepe_Pulse",

    port="5432"
)

mycursor = mydb.cursor()

# %%
# # Creating new database and tables
# mycursor.execute("CREATE DATABASE Phonepe_pulse")
# mycursor.execute("USE Phonepe_pulse")
# Out:
# ---------------------------------------------------------------------------
# ActiveSqlTransaction                      Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Creating new database and tables
# ----> 2 mycursor.execute("CREATE DATABASE Phonepe_pulse")
#       3 mycursor.execute("USE Phonepe_pulse")
#
# ActiveSqlTransaction: CREATE DATABASE cannot run inside a transaction block

# %%
import psycopg2

mydb = psycopg2.connect(
    host="localhost",
    user="postgres",
    password="Iphone14pro",
    database="Phonepe_Pulse",
    port="5432"
)

mycursor = mydb.cursor()

# Creating agg_trans table
mycursor.execute("CREATE TABLE agg_trans (State varchar(100), Year int, Quarter int, Transaction_type varchar(100), Transaction_count int, Transaction_amount double precision)")

for i,row in df_agg_trans.iterrows():
    #here %S means string values 
    sql = "INSERT INTO agg_trans VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    # the connection is not auto committed by default, so we must commit to save our changes
    mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# Cell In[19], line 14
#      11 mycursor = mydb.cursor()
#      13 # Creating agg_trans table
# ---> 14 mycursor.execute("CREATE TABLE agg_trans (State varchar(100), Year int, Quarter int, Transaction_type varchar(100), Transaction_count int, Transaction_amount double precision)")
#      16 for i,row in df_agg_trans.iterrows():
#      17     #here %S means string values
#      18     sql = "INSERT INTO agg_trans VALUES (%s,%s,%s,%s,%s,%s)"
#
# DuplicateTable: relation "agg_trans" already exists

# %%
mydb = psycopg2.connect(
    host="localhost",
    user="postgres",
    password="Iphone14pro",
    database="Phonepe_Pulse",
    port="5432"
)

mycursor = mydb.cursor()

# Creating agg_trans table
mycursor.execute("CREATE TABLE agg_user (State varchar(100), Year int, Quarter int, Brands varchar(100), Count int, Percentage double precision)")

for i,row in df_agg_user.iterrows():
    sql = "INSERT INTO agg_user VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# Cell In[20], line 12
#       9 mycursor = mydb.cursor()
#      11 # Creating agg_trans table
# ---> 12 mycursor.execute("CREATE TABLE agg_user (State varchar(100), Year int, Quarter int, Brands varchar(100), Count int, Percentage double precision)")
#      14 for i,row in df_agg_user.iterrows():
#      15     sql = "INSERT INTO agg_user VALUES (%s,%s,%s,%s,%s,%s)"
#
# DuplicateTable: relation "agg_user" already exists

# %%
mydb = psycopg2.connect(
    host="localhost",
    user="postgres",
    password="Iphone14pro",
    database="Phonepe_Pulse",
    port="5432"
)

mycursor = mydb.cursor()

# Creating agg_trans table
mycursor.execute("CREATE TABLE map_trans (State varchar(100), Year int, Quarter int, District varchar(100), Count int, Amount double precision)")

for i,row in df_map_trans.iterrows():
    sql = "INSERT INTO map_trans VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# Cell In[21], line 12
#       9 mycursor = mydb.cursor()
#      11 # Creating agg_trans table
# ---> 12 mycursor.execute("CREATE TABLE map_trans (State varchar(100), Year int, Quarter int, District varchar(100), Count int, Amount double precision)")
#      14 for i,row in df_map_trans.iterrows():
#      15     sql = "INSERT INTO map_trans VALUES (%s,%s,%s,%s,%s,%s)"
#
# DuplicateTable: relation "map_trans" already exists

# %%
mydb = psycopg2.connect(
    host="localhost",
    user="postgres",
    password="Iphone14pro",
    database="Phonepe_Pulse",
    port="5432"
)

mycursor = mydb.cursor()

# Creating agg_trans table
mycursor.execute("CREATE TABLE map_user (State varchar(100), Year int, Quarter int, District varchar(100), Registered_user int, App_opens int)")

for i,row in df_map_user.iterrows():
    sql = "INSERT INTO map_user VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# Cell In[22], line 12
#       9 mycursor = mydb.cursor()
#      11 # Creating agg_trans table
# ---> 12 mycursor.execute("CREATE TABLE map_user (State varchar(100), Year int, Quarter int, District varchar(100), Registered_user int, App_opens int)")
#      14 for i,row in df_map_user.iterrows():
#      15     sql = "INSERT INTO map_user VALUES (%s,%s,%s,%s,%s,%s)"
#
# DuplicateTable: relation "map_user" already exists

# %%
mydb = psycopg2.connect(
    host="localhost",
    user="postgres",
    password="Iphone14pro",
    database="Phonepe_Pulse",
    port="5432"
)

mycursor = mydb.cursor()
# Creating top_trans table
mycursor.execute("CREATE TABLE top_trans (\"State\" VARCHAR(100), \"Year\" INT, \"Quarter\" INT, \"Pincodes\" INT, \"Transaction_count\" INT, \"Transaction_amount\" INT)")

# mycursor.execute("create table top_trans (State varchar(100), Year int, Quarter int, Pincode int, Transaction_count int, Transaction_amount )")

for i,row in df_top_trans.iterrows():
    sql = "INSERT INTO top_trans VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# Cell In[42], line 11
#       9 mycursor = mydb.cursor()
#      10 # Creating top_trans table
# ---> 11 mycursor.execute("CREATE TABLE top_trans (\"State\" VARCHAR(100), \"Year\" INT, \"Quarter\" INT, \"Pincodes\" INT, \"Transaction_count\" INT, \"Transaction_amount\" INT)")
#      13 # mycursor.execute("create table top_trans (State varchar(100), Year int, Quarter int, Pincode int, Transaction_count int, Transaction_amount )")
#      15 for i,row in df_top_trans.iterrows():
#
# DuplicateTable: relation "top_trans" already exists

# %%
mydb = psycopg2.connect(
    host="localhost",
    user="postgres",
    password="Iphone14pro",
    database="Phonepe_Pulse",
    port="5432"
)

mycursor = mydb.cursor()

# Creating top_user table


mycursor.execute("create table top_user (State varchar(100), Year int, Quarter int, Pincodes varchar(255), RegisteredUsers int)")

for i,row in df_top_user.iterrows():
    sql = "INSERT INTO top_user VALUES (%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()

# %%
mydb.rollback()
mycursor.execute("SELECT table_name FROM information_schema.tables WHERE table_schema='public'")
tables = mycursor.fetchall()
table_names = [table[0] for table in tables]
print(table_names)
# Out:
# ['agg_trans', 'top_transaction', 'agg_user', 'top_trans', 'top_user', 'map_trans', 'map_user']

# %%
[('agg_trans',),
 ('agg_user',),
 ('map_trans',),
 ('map_user',),
 ('top_trans',),
 ('top_user',)]
# Out:
# [('agg_trans',),
#  ('agg_user',),
#  ('map_trans',),
#  ('map_user',),
#  ('top_trans',),
#  ('top_user',)]
